# %%
import cv2

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/taylor.jpg')
img.shape
# Out:
# (360, 640, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (360, 640)

# %%
gray
# Out:
# array([[249, 249, 248, ..., 255, 255, 255],
#        [249, 249, 248, ..., 255, 255, 255],
#        [249, 249, 248, ..., 255, 255, 255],
#        ...,
#        [242, 242, 242, ..., 224, 224, 224],
#        [242, 242, 242, ..., 224, 224, 224],
#        [242, 242, 242, ..., 224, 224, 224]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[221,  46, 179, 179]])

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[221,  46, 179, 179]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (221, 46, 179, 179)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is not None:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                            return roi_color

# %%
original_image = cv2.imread('./test_images/taylor.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/taylor.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/taylor1.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/taylor1.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/alec_benjamin',
#  './dataset/ar_rahman',
#  './dataset/illayaraja',
#  './dataset/shreya_ghoshal',
#  './dataset/taylor_swift']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# alec_benjamin
# Generating cropped images in folder:  ./dataset/cropped/alec_benjamin
# ar_rahman
# Generating cropped images in folder:  ./dataset/cropped/ar_rahman
# illayaraja
# Generating cropped images in folder:  ./dataset/cropped/illayaraja
# shreya_ghoshal
# Generating cropped images in folder:  ./dataset/cropped/shreya_ghoshal
# taylor_swift
# Generating cropped images in folder:  ./dataset/cropped/taylor_swift

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'alec_benjamin': ['./dataset/cropped/alec_benjamin/alec_benjamin1.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin2.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin3.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin4.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin5.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin6.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin7.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin8.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin9.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin10.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin11.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin12.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin13.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin14.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin15.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin16.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin17.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin18.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin19.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin20.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin21.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin22.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin23.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin24.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin25.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin26.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin27.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin28.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin29.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin30.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin31.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin32.png',
#   './dataset/cropped/alec_benjamin/alec_benjamin33.png'],
#  'ar_rahman': ['./dataset/cropped/ar_rahman/ar_rahman1.png',
#   './dataset/cropped/ar_rahman/ar_rahman2.png',
#   './dataset/cropped/ar_rahman/ar_rahman3.png',
#   './dataset/cropped/ar_rahman/ar_rahman4.png',
#   './dataset/cropped/ar_rahman/ar_rahman5.png',
#   './dataset/cropped/ar_rahman/ar_rahman6.png',
#   './dataset/cropped/ar_rahman/ar_rahman7.png',
#   './dataset/cropped/ar_rahman/ar_rahman8.png',
#   './dataset/cropped/ar_rahman/ar_rahman9.png',
#   './dataset/cropped/ar_rahman/ar_rahman10.png',
#   './dataset/cropped/ar_rahman/ar_rahman11.png',
#   './dataset/cropped/ar_rahman/ar_rahman12.png',
#   './dataset/cropped/ar_rahman/ar_rahman13.png',
#   './dataset/cropped/ar_rahman/ar_rahman14.png',
#   './dataset/cropped/ar_rahman/ar_rahman15.png',
#   './dataset/cropped/ar_rahman/ar_rahman16.png',
#   './dataset/cropped/ar_rahman/ar_rahman17.png',
#   './dataset/cropped/ar_rahman/ar_rahman18.png',
#   './dataset/cropped/ar_rahman/ar_rahman19.png',
#   './dataset/cropped/ar_rahman/ar_rahman20.png',
#   './dataset/cropped/ar_rahman/ar_rahman21.png',
#   './dataset/cropped/ar_rahman/ar_rahman22.png',
#   './dataset/cropped/ar_rahman/ar_rahman23.png',
#   './dataset/cropped/ar_rahman/ar_rahman24.png',
#   './dataset/cropped/ar_rahman/ar_rahman25.png',
#   './dataset/cropped/ar_rahman/ar_rahman26.png',
#   './dataset/cropped/ar_rahman/ar_rahman27.png',
#   './dataset/cropped/ar_rahman/ar_rahman28.png',
#   './dataset/cropped/ar_rahman/ar_rahman29.png',
#   './dataset/cropped/ar_rahman/ar_rahman30.png',
#   './dataset/cropped/ar_rahman/ar_rahman31.png',
#   './dataset/cropped/ar_rahman/ar_rahman32.png',
#   './dataset/cropped/ar_rahman/ar_rahman33.png',
#   './dataset/cropped/ar_rahman/ar_rahman34.png',
#   './dataset/cropped/ar_rahman/ar_rahman35.png',
#   './dataset/cropped/ar_rahman/ar_rahman36.png',
#   './dataset/cropped/ar_rahman/ar_rahman37.png',
#   './dataset/cropped/ar_rahman/ar_rahman38.png',
#   './dataset/cropped/ar_rahman/ar_rahman39.png',
#   './dataset/cropped/ar_rahman/ar_rahman40.png',
#   './dataset/cropped/ar_rahman/ar_rahman41.png',
#   './dataset/cropped/ar_rahman/ar_rahman42.png',
#   './dataset/cropped/ar_rahman/ar_rahman43.png',
#   './dataset/cropped/ar_rahman/ar_rahman44.png',
#   './dataset/cropped/ar_rahman/ar_rahman45.png',
#   './dataset/cropped/ar_rahman/ar_rahman46.png',
#   './dataset/cropped/ar_rahman/ar_rahman47.png',
#   './dataset/cropped/ar_rahman/ar_rahman48.png',
#   './dataset/cropped/ar_rahman/ar_rahman49.png',
#   './dataset/cropped/ar_rahman/ar_rahman50.png',
#   './dataset/cropped/ar_rahman/ar_rahman51.png'],
#  'illayaraja': ['./dataset/cropped/illayaraja/illayaraja1.png',
#   './dataset/cropped/illayaraja/illayaraja2.png',
#   './dataset/cropped/illayaraja/illayaraja3.png',
#   './dataset/cropped/illayaraja/illayaraja4.png',
#   './dataset/cropped/illayaraja/illayaraja5.png',
#   './dataset/cropped/illayaraja/illayaraja6.png',
#   './dataset/cropped/illayaraja/illayaraja7.png',
#   './dataset/cropped/illayaraja/illayaraja8.png',
#   './dataset/cropped/illayaraja/illayaraja9.png',
#   './dataset/cropped/illayaraja/illayaraja10.png',
#   './dataset/cropped/illayaraja/illayaraja11.png',
#   './dataset/cropped/illayaraja/illayaraja12.png',
#   './dataset/cropped/illayaraja/illayaraja13.png',
#   './dataset/cropped/illayaraja/illayaraja14.png',
#   './dataset/cropped/illayaraja/illayaraja15.png',
#   './dataset/cropped/illayaraja/illayaraja16.png',
#   './dataset/cropped/illayaraja/illayaraja17.png',
#   './dataset/cropped/illayaraja/illayaraja18.png',
#   './dataset/cropped/illayaraja/illayaraja19.png',
#   './dataset/cropped/illayaraja/illayaraja20.png',
#   './dataset/cropped/illayaraja/illayaraja21.png',
#   './dataset/cropped/illayaraja/illayaraja22.png',
#   './dataset/cropped/illayaraja/illayaraja23.png',
#   './dataset/cropped/illayaraja/illayaraja24.png',
#   './dataset/cropped/illayaraja/illayaraja25.png',
#   './dataset/cropped/illayaraja/illayaraja26.png',
#   './dataset/cropped/illayaraja/illayaraja27.png',
#   './dataset/cropped/illayaraja/illayaraja28.png',
#   './dataset/cropped/illayaraja/illayaraja29.png',
#   './dataset/cropped/illayaraja/illayaraja30.png',
#   './dataset/cropped/illayaraja/illayaraja31.png',
#   './dataset/cropped/illayaraja/illayaraja32.png',
#   './dataset/cropped/illayaraja/illayaraja33.png',
#   './dataset/cropped/illayaraja/illayaraja34.png',
#   './dataset/cropped/illayaraja/illayaraja35.png',
#   './dataset/cropped/illayaraja/illayaraja36.png',
#   './dataset/cropped/illayaraja/illayaraja37.png',
#   './dataset/cropped/illayaraja/illayaraja38.png',
#   './dataset/cropped/illayaraja/illayaraja39.png',
#   './dataset/cropped/illayaraja/illayaraja40.png',
#   './dataset/cropped/illayaraja/illayaraja41.png',
#   './dataset/cropped/illayaraja/illayaraja42.png',
#   './dataset/cropped/illayaraja/illayaraja43.png',
#   './dataset/cropped/illayaraja/illayaraja44.png',
#   './dataset/cropped/illayaraja/illayaraja45.png',
#   './dataset/cropped/illayaraja/illayaraja46.png',
#   './dataset/cropped/illayaraja/illayaraja47.png',
#   './dataset/cropped/illayaraja/illayaraja48.png',
#   './dataset/cropped/illayaraja/illayaraja49.png',
#   './dataset/cropped/illayaraja/illayaraja50.png',
#   './dataset/cropped/illayaraja/illayaraja51.png',
#   './dataset/cropped/illayaraja/illayaraja52.png',
#   './dataset/cropped/illayaraja/illayaraja53.png',
#   './dataset/cropped/illayaraja/illayaraja54.png',
#   './dataset/cropped/illayaraja/illayaraja55.png'],
#  'shreya_ghoshal': ['./dataset/cropped/shreya_ghoshal/shreya_ghoshal1.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal2.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal3.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal4.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal5.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal6.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal7.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal8.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal9.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal10.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal11.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal12.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal13.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal14.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal15.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal16.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal17.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal18.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal19.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal20.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal21.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal22.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal23.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal24.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal25.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal26.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal27.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal28.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal29.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal30.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal31.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal32.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal33.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal34.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal35.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal36.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal37.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal38.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal39.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal40.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal41.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal42.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal43.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal44.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal45.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal46.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal47.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal48.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal49.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal50.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal51.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal52.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal53.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal54.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal55.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal56.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal57.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal58.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal59.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal60.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal61.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal62.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal63.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal64.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal65.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal66.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal67.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal68.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal69.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal70.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal71.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal72.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal73.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal74.png',
#   './dataset/cropped/shreya_ghoshal/shreya_ghoshal75.png'],
#  'taylor_swift': ['./dataset/cropped/taylor_swift/taylor_swift1.png',
#   './dataset/cropped/taylor_swift/taylor_swift2.png',
#   './dataset/cropped/taylor_swift/taylor_swift3.png',
#   './dataset/cropped/taylor_swift/taylor_swift4.png',
#   './dataset/cropped/taylor_swift/taylor_swift5.png',
#   './dataset/cropped/taylor_swift/taylor_swift6.png',
#   './dataset/cropped/taylor_swift/taylor_swift7.png',
#   './dataset/cropped/taylor_swift/taylor_swift8.png',
#   './dataset/cropped/taylor_swift/taylor_swift9.png',
#   './dataset/cropped/taylor_swift/taylor_swift10.png',
#   './dataset/cropped/taylor_swift/taylor_swift11.png',
#   './dataset/cropped/taylor_swift/taylor_swift12.png',
#   './dataset/cropped/taylor_swift/taylor_swift13.png',
#   './dataset/cropped/taylor_swift/taylor_swift14.png',
#   './dataset/cropped/taylor_swift/taylor_swift15.png',
#   './dataset/cropped/taylor_swift/taylor_swift16.png',
#   './dataset/cropped/taylor_swift/taylor_swift17.png',
#   './dataset/cropped/taylor_swift/taylor_swift18.png',
#   './dataset/cropped/taylor_swift/taylor_swift19.png',
#   './dataset/cropped/taylor_swift/taylor_swift20.png',
#   './dataset/cropped/taylor_swift/taylor_swift21.png',
#   './dataset/cropped/taylor_swift/taylor_swift22.png',
#   './dataset/cropped/taylor_swift/taylor_swift23.png',
#   './dataset/cropped/taylor_swift/taylor_swift24.png',
#   './dataset/cropped/taylor_swift/taylor_swift25.png',
#   './dataset/cropped/taylor_swift/taylor_swift26.png',
#   './dataset/cropped/taylor_swift/taylor_swift27.png',
#   './dataset/cropped/taylor_swift/taylor_swift28.png',
#   './dataset/cropped/taylor_swift/taylor_swift29.png',
#   './dataset/cropped/taylor_swift/taylor_swift30.png',
#   './dataset/cropped/taylor_swift/taylor_swift31.png',
#   './dataset/cropped/taylor_swift/taylor_swift32.png',
#   './dataset/cropped/taylor_swift/taylor_swift33.png',
#   './dataset/cropped/taylor_swift/taylor_swift34.png',
#   './dataset/cropped/taylor_swift/taylor_swift35.png',
#   './dataset/cropped/taylor_swift/taylor_swift36.png',
#   './dataset/cropped/taylor_swift/taylor_swift37.png',
#   './dataset/cropped/taylor_swift/taylor_swift38.png',
#   './dataset/cropped/taylor_swift/taylor_swift39.png',
#   './dataset/cropped/taylor_swift/taylor_swift40.png',
#   './dataset/cropped/taylor_swift/taylor_swift41.png',
#   './dataset/cropped/taylor_swift/taylor_swift42.png',
#   './dataset/cropped/taylor_swift/taylor_swift43.png',
#   './dataset/cropped/taylor_swift/taylor_swift44.png',
#   './dataset/cropped/taylor_swift/taylor_swift45.png',
#   './dataset/cropped/taylor_swift/taylor_swift46.png',
#   './dataset/cropped/taylor_swift/taylor_swift47.png',
#   './dataset/cropped/taylor_swift/taylor_swift48.png',
#   './dataset/cropped/taylor_swift/taylor_swift49.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'alec_benjamin': 0,
#  'ar_rahman': 1,
#  'illayaraja': 2,
#  'shreya_ghoshal': 3,
#  'taylor_swift': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 40],
#        [ 35],
#        [ 44],
#        ...,
#        [180],
#        [249],
#        [210]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (197, 4096)

# %%
X[0]
# Out:
# array([ 40.,  35.,  44., ..., 180., 249., 210.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C =10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.82

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.62      0.77         8
#            1       0.83      0.62      0.71         8
#            2       0.75      1.00      0.86         6
#            3       0.80      0.94      0.86        17
#            4       0.82      0.82      0.82        11
#
#     accuracy                           0.82        50
#    macro avg       0.84      0.80      0.80        50
# weighted avg       0.84      0.82      0.81        50

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.870805
# 1        random_forest    0.693793
# 2  logistic_regression    0.877701
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.96

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.62

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.94

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  0,  0,  0,  0],
#        [ 1,  7,  0,  0,  0],
#        [ 0,  0,  6,  0,  0],
#        [ 0,  0,  0, 17,  0],
#        [ 0,  0,  0,  1, 10]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'alec_benjamin': 0,
#  'ar_rahman': 1,
#  'illayaraja': 2,
#  'shreya_ghoshal': 3,
#  'taylor_swift': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
