# %%
import cv2

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/virat.jpg')
img.shape
# Out:
# (1350, 1080, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1350, 1080)

# %%
gray
# Out:
# array([[111, 111, 111, ..., 114, 114, 114],
#        [111, 111, 111, ..., 114, 114, 114],
#        [111, 111, 111, ..., 114, 114, 114],
#        ...,
#        [  9,   9,   9, ...,   6,   6,   6],
#        [  9,   9,   9, ...,   6,   6,   6],
#        [  9,   9,   9, ...,   6,   6,   6]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[333, 130, 368, 368]])

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[333, 130, 368, 368]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (333, 130, 368, 368)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is not None:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                            return roi_color

# %%
original_image = cv2.imread('./test_images/virat.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/virat.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/virat2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/virat2.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/maria_sharapova',
#  './dataset/messi',
#  './dataset/ronaldo',
#  './dataset/serena_williams',
#  './dataset/yuvraj_singh']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# maria_sharapova
# Generating cropped images in folder:  ./dataset/cropped/maria_sharapova
# messi
# Generating cropped images in folder:  ./dataset/cropped/messi
# ronaldo
# Generating cropped images in folder:  ./dataset/cropped/ronaldo
# serena_williams
# Generating cropped images in folder:  ./dataset/cropped/serena_williams
# yuvraj_singh
# Generating cropped images in folder:  ./dataset/cropped/yuvraj_singh

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'maria_sharapova': ['./dataset/cropped/maria_sharapova/maria_sharapova1.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova2.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova3.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova4.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova5.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova6.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova7.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova8.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova9.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova10.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova11.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova12.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova13.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova14.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova15.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova16.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova17.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova18.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova19.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova20.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova21.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova22.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova23.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova24.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova25.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova26.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova27.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova28.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova29.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova30.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova31.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova32.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova33.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova34.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova35.png',
#   './dataset/cropped/maria_sharapova/maria_sharapova36.png'],
#  'messi': ['./dataset/cropped/messi/messi1.png',
#   './dataset/cropped/messi/messi2.png',
#   './dataset/cropped/messi/messi3.png',
#   './dataset/cropped/messi/messi4.png',
#   './dataset/cropped/messi/messi5.png',
#   './dataset/cropped/messi/messi6.png',
#   './dataset/cropped/messi/messi7.png',
#   './dataset/cropped/messi/messi8.png',
#   './dataset/cropped/messi/messi9.png',
#   './dataset/cropped/messi/messi10.png',
#   './dataset/cropped/messi/messi11.png',
#   './dataset/cropped/messi/messi12.png',
#   './dataset/cropped/messi/messi13.png',
#   './dataset/cropped/messi/messi14.png',
#   './dataset/cropped/messi/messi15.png',
#   './dataset/cropped/messi/messi16.png',
#   './dataset/cropped/messi/messi17.png',
#   './dataset/cropped/messi/messi18.png',
#   './dataset/cropped/messi/messi19.png',
#   './dataset/cropped/messi/messi20.png',
#   './dataset/cropped/messi/messi21.png',
#   './dataset/cropped/messi/messi22.png',
#   './dataset/cropped/messi/messi23.png',
#   './dataset/cropped/messi/messi24.png',
#   './dataset/cropped/messi/messi25.png',
#   './dataset/cropped/messi/messi26.png',
#   './dataset/cropped/messi/messi27.png',
#   './dataset/cropped/messi/messi28.png',
#   './dataset/cropped/messi/messi29.png',
#   './dataset/cropped/messi/messi30.png',
#   './dataset/cropped/messi/messi31.png',
#   './dataset/cropped/messi/messi32.png',
#   './dataset/cropped/messi/messi33.png',
#   './dataset/cropped/messi/messi34.png',
#   './dataset/cropped/messi/messi35.png',
#   './dataset/cropped/messi/messi36.png',
#   './dataset/cropped/messi/messi37.png',
#   './dataset/cropped/messi/messi38.png',
#   './dataset/cropped/messi/messi39.png',
#   './dataset/cropped/messi/messi40.png',
#   './dataset/cropped/messi/messi41.png',
#   './dataset/cropped/messi/messi42.png',
#   './dataset/cropped/messi/messi43.png',
#   './dataset/cropped/messi/messi44.png',
#   './dataset/cropped/messi/messi45.png'],
#  'ronaldo': ['./dataset/cropped/ronaldo/ronaldo1.png',
#   './dataset/cropped/ronaldo/ronaldo2.png',
#   './dataset/cropped/ronaldo/ronaldo3.png',
#   './dataset/cropped/ronaldo/ronaldo4.png',
#   './dataset/cropped/ronaldo/ronaldo5.png',
#   './dataset/cropped/ronaldo/ronaldo6.png',
#   './dataset/cropped/ronaldo/ronaldo7.png',
#   './dataset/cropped/ronaldo/ronaldo8.png',
#   './dataset/cropped/ronaldo/ronaldo9.png',
#   './dataset/cropped/ronaldo/ronaldo10.png',
#   './dataset/cropped/ronaldo/ronaldo11.png',
#   './dataset/cropped/ronaldo/ronaldo12.png',
#   './dataset/cropped/ronaldo/ronaldo13.png',
#   './dataset/cropped/ronaldo/ronaldo14.png',
#   './dataset/cropped/ronaldo/ronaldo15.png',
#   './dataset/cropped/ronaldo/ronaldo16.png',
#   './dataset/cropped/ronaldo/ronaldo17.png',
#   './dataset/cropped/ronaldo/ronaldo18.png',
#   './dataset/cropped/ronaldo/ronaldo19.png',
#   './dataset/cropped/ronaldo/ronaldo20.png',
#   './dataset/cropped/ronaldo/ronaldo21.png',
#   './dataset/cropped/ronaldo/ronaldo22.png',
#   './dataset/cropped/ronaldo/ronaldo23.png',
#   './dataset/cropped/ronaldo/ronaldo24.png',
#   './dataset/cropped/ronaldo/ronaldo25.png',
#   './dataset/cropped/ronaldo/ronaldo26.png',
#   './dataset/cropped/ronaldo/ronaldo27.png',
#   './dataset/cropped/ronaldo/ronaldo28.png',
#   './dataset/cropped/ronaldo/ronaldo29.png',
#   './dataset/cropped/ronaldo/ronaldo30.png',
#   './dataset/cropped/ronaldo/ronaldo31.png',
#   './dataset/cropped/ronaldo/ronaldo32.png',
#   './dataset/cropped/ronaldo/ronaldo33.png',
#   './dataset/cropped/ronaldo/ronaldo34.png',
#   './dataset/cropped/ronaldo/ronaldo35.png',
#   './dataset/cropped/ronaldo/ronaldo36.png',
#   './dataset/cropped/ronaldo/ronaldo37.png',
#   './dataset/cropped/ronaldo/ronaldo38.png',
#   './dataset/cropped/ronaldo/ronaldo39.png',
#   './dataset/cropped/ronaldo/ronaldo40.png',
#   './dataset/cropped/ronaldo/ronaldo41.png',
#   './dataset/cropped/ronaldo/ronaldo42.png',
#   './dataset/cropped/ronaldo/ronaldo43.png',
#   './dataset/cropped/ronaldo/ronaldo44.png',
#   './dataset/cropped/ronaldo/ronaldo45.png',
#   './dataset/cropped/ronaldo/ronaldo46.png',
#   './dataset/cropped/ronaldo/ronaldo47.png',
#   './dataset/cropped/ronaldo/ronaldo48.png',
#   './dataset/cropped/ronaldo/ronaldo49.png',
#   './dataset/cropped/ronaldo/ronaldo50.png',
#   './dataset/cropped/ronaldo/ronaldo51.png',
#   './dataset/cropped/ronaldo/ronaldo52.png',
#   './dataset/cropped/ronaldo/ronaldo53.png',
#   './dataset/cropped/ronaldo/ronaldo54.png',
#   './dataset/cropped/ronaldo/ronaldo55.png',
#   './dataset/cropped/ronaldo/ronaldo56.png',
#   './dataset/cropped/ronaldo/ronaldo57.png',
#   './dataset/cropped/ronaldo/ronaldo58.png',
#   './dataset/cropped/ronaldo/ronaldo59.png',
#   './dataset/cropped/ronaldo/ronaldo60.png',
#   './dataset/cropped/ronaldo/ronaldo61.png',
#   './dataset/cropped/ronaldo/ronaldo62.png',
#   './dataset/cropped/ronaldo/ronaldo63.png',
#   './dataset/cropped/ronaldo/ronaldo64.png',
#   './dataset/cropped/ronaldo/ronaldo65.png',
#   './dataset/cropped/ronaldo/ronaldo66.png',
#   './dataset/cropped/ronaldo/ronaldo67.png',
#   './dataset/cropped/ronaldo/ronaldo68.png',
#   './dataset/cropped/ronaldo/ronaldo69.png',
#   './dataset/cropped/ronaldo/ronaldo70.png',
#   './dataset/cropped/ronaldo/ronaldo71.png',
#   './dataset/cropped/ronaldo/ronaldo72.png',
#   './dataset/cropped/ronaldo/ronaldo73.png',
#   './dataset/cropped/ronaldo/ronaldo74.png',
#   './dataset/cropped/ronaldo/ronaldo75.png',
#   './dataset/cropped/ronaldo/ronaldo76.png',
#   './dataset/cropped/ronaldo/ronaldo77.png',
#   './dataset/cropped/ronaldo/ronaldo78.png',
#   './dataset/cropped/ronaldo/ronaldo79.png',
#   './dataset/cropped/ronaldo/ronaldo80.png',
#   './dataset/cropped/ronaldo/ronaldo81.png',
#   './dataset/cropped/ronaldo/ronaldo82.png'],
#  'serena_williams': ['./dataset/cropped/serena_williams/serena_williams1.png',
#   './dataset/cropped/serena_williams/serena_williams2.png',
#   './dataset/cropped/serena_williams/serena_williams3.png',
#   './dataset/cropped/serena_williams/serena_williams4.png',
#   './dataset/cropped/serena_williams/serena_williams5.png',
#   './dataset/cropped/serena_williams/serena_williams6.png',
#   './dataset/cropped/serena_williams/serena_williams7.png',
#   './dataset/cropped/serena_williams/serena_williams8.png',
#   './dataset/cropped/serena_williams/serena_williams9.png',
#   './dataset/cropped/serena_williams/serena_williams10.png',
#   './dataset/cropped/serena_williams/serena_williams11.png',
#   './dataset/cropped/serena_williams/serena_williams12.png',
#   './dataset/cropped/serena_williams/serena_williams13.png',
#   './dataset/cropped/serena_williams/serena_williams14.png',
#   './dataset/cropped/serena_williams/serena_williams15.png',
#   './dataset/cropped/serena_williams/serena_williams16.png',
#   './dataset/cropped/serena_williams/serena_williams17.png',
#   './dataset/cropped/serena_williams/serena_williams18.png',
#   './dataset/cropped/serena_williams/serena_williams19.png',
#   './dataset/cropped/serena_williams/serena_williams20.png',
#   './dataset/cropped/serena_williams/serena_williams21.png',
#   './dataset/cropped/serena_williams/serena_williams22.png',
#   './dataset/cropped/serena_williams/serena_williams23.png',
#   './dataset/cropped/serena_williams/serena_williams24.png',
#   './dataset/cropped/serena_williams/serena_williams25.png',
#   './dataset/cropped/serena_williams/serena_williams26.png',
#   './dataset/cropped/serena_williams/serena_williams27.png',
#   './dataset/cropped/serena_williams/serena_williams28.png',
#   './dataset/cropped/serena_williams/serena_williams29.png',
#   './dataset/cropped/serena_williams/serena_williams30.png',
#   './dataset/cropped/serena_williams/serena_williams31.png',
#   './dataset/cropped/serena_williams/serena_williams32.png',
#   './dataset/cropped/serena_williams/serena_williams33.png',
#   './dataset/cropped/serena_williams/serena_williams34.png',
#   './dataset/cropped/serena_williams/serena_williams35.png'],
#  'yuvraj_singh': ['./dataset/cropped/yuvraj_singh/yuvraj_singh1.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh2.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh3.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh4.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh5.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh6.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh7.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh8.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh9.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh10.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh11.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh12.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh13.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh14.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh15.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh16.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh17.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh18.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh19.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh20.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh21.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh22.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh23.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh24.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh25.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh26.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh27.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh28.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh29.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh30.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh31.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh32.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh33.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh34.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh35.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh36.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh37.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh38.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh39.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh40.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh41.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh42.png',
#   './dataset/cropped/yuvraj_singh/yuvraj_singh43.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'maria_sharapova': 0,
#  'messi': 1,
#  'ronaldo': 2,
#  'serena_williams': 3,
#  'yuvraj_singh': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[117],
#        [113],
#        [126],
#        ...,
#        [253],
#        [247],
#        [ 25]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (184, 4096)

# %%
X[0]
# Out:
# array([117., 113., 126., ..., 253., 247.,  25.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C =10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8043478260869565

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.80      0.40      0.53        10
#            2       0.73      1.00      0.84        16
#            3       1.00      1.00      1.00         6
#            4       0.75      0.86      0.80         7
#
#     accuracy                           0.80        46
#    macro avg       0.86      0.79      0.80        46
# weighted avg       0.82      0.80      0.79        46

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.767989
# 1        random_forest    0.550529
# 2  logistic_regression    0.732804
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8478260869565217

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6739130434782609

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8695652173913043

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 5,  0,  2,  0,  0],
#        [ 0,  8,  1,  0,  1],
#        [ 0,  1, 14,  1,  0],
#        [ 0,  0,  0,  6,  0],
#        [ 0,  1,  0,  0,  6]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'maria_sharapova': 0,
#  'messi': 1,
#  'ronaldo': 2,
#  'serena_williams': 3,
#  'yuvraj_singh': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
